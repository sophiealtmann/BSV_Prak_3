# %%
import numpy as np
from scipy import fftpack
from scipy import signal
import matplotlib.pyplot as plt
import pandas as pd
import Lab3Functions as lf3
import Functions as fun

# %%
# Daten importieren
weights,mvc,fatigue=lf3.import_data("\t")
# Out:
# c:\Users\sophi\Desktop\BSV_Praktikum\BSV_Prak_3\Python Code\Lab3Functions.py:144: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   weights_raw = weights_raw.append(pd.read_csv(
# c:\Users\sophi\Desktop\BSV_Praktikum\BSV_Prak_3\Python Code\Lab3Functions.py:144: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   weights_raw = weights_raw.append(pd.read_csv(
# c:\Users\sophi\Desktop\BSV_Praktikum\BSV_Prak_3\Python Code\Lab3Functions.py:149: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   mvc_raw = mvc_raw.append(pd.read_csv(
# c:\Users\sophi\Desktop\BSV_Praktikum\BSV_Prak_3\Python Code\Lab3Functions.py:149: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mvc_raw = mvc_raw.append(pd.read_csv(
# c:\Users\sophi\Desktop\BSV_Praktikum\BSV_Prak_3\Python Code\Lab3Functions.py:154: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   fatigue_raw = fatigue_raw.append(pd.read_csv(
# c:\Users\sophi\Desktop\BSV_Praktikum\BSV_Prak_3\Python Code\Lab3Functions.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fatigue_raw = fatigue_raw.append(pd.read_csv(
# c:\Users\sophi\Desktop\BSV_Praktikum\BSV_Prak_3\Python Code\Lab3Functions.py:144: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   weights_raw = weights_raw.append(pd.read_csv(
# c:\Users\sophi\Desktop\BSV_Praktikum\BSV_Prak_3\Python Code\Lab3Functions.py:144: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   weights_raw = weights_raw.append(pd.read_csv(
# c:\Users\sophi\Desktop\BSV_Praktikum\BSV_Prak_3\Python Code\Lab3Functions.py:149: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   mvc_raw = mvc_raw.append(pd.read_csv(
# c:\Users\sophi\Desktop\BSV_Praktikum\BSV_Prak_3\Python Code\Lab3Functions.py:149: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mvc_raw = mvc_raw.append(pd.read_csv(
# c:\Users\sophi\Desktop\BSV_Praktikum\BSV_Prak_3\Python Code\Lab3Functions.py:154: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   fatigue_raw = fatigue_raw.append(pd.read_csv(
# c:\Users\sophi\Desktop\BSV_Praktikum\BSV_Prak_3\Python Code\Lab3Functions.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fatigue_raw = fatigue_raw.append(pd.read_csv(
# c:\Users\sophi\Desktop\BSV_Praktikum\BSV_Prak_3\Python Code\Lab3Functions.py:144: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   weights_raw = weights_raw.append(pd.read_csv(
# c:\Users\sophi\Desktop\BSV_Praktikum\BSV_Prak_3\Python Code\Lab3Functions.py:144: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   weights_raw = weights_raw.append(pd.read_csv(
# c:\Users\sophi\Desktop\BSV_Praktikum\BSV_Prak_3\Python Code\Lab3Functions.py:149: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   mvc_raw = mvc_raw.append(pd.read_csv(
# c:\Users\sophi\Desktop\BSV_Praktikum\BSV_Prak_3\Python Code\Lab3Functions.py:149: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mvc_raw = mvc_raw.append(pd.read_csv(
# c:\Users\sophi\Desktop\BSV_Praktikum\BSV_Prak_3\Python Code\Lab3Functions.py:154: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   fatigue_raw = fatigue_raw.append(pd.read_csv(
# c:\Users\sophi\Desktop\BSV_Praktikum\BSV_Prak_3\Python Code\Lab3Functions.py:154: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fatigue_raw = fatigue_raw.append(pd.read_csv(

# %%
# Offset eliminieren
nooffset= fun.eliminateoffset(fatigue.emg, fatigue.t)

# %%
# Filtern zwischen 20 und 450 Hz
emg_filtered = fun.filter(nooffset, fatigue.t)
# Out:
# [0.012718010928653798 -0.024699716589927583 0.03471077654222201 ...
#  0.027023580453110353 -0.01152307857197778 -0.0027736439002972796]

# %%
em_gleich = fun.gleich(nooffset, fatigue.t, emg_filtered)

# %%
fun.huelle(nooffset, fatigue.t, em_gleich, 3)

# %%
mvc_offset=fun.eliminateoffset(mvc.emg, mvc.t)
weights_offset=fun.eliminateoffset(weights.emg, weights.t)
fatigue_offset=fun.eliminateoffset(fatigue.emg, fatigue.t)

mvc_filtered=fun.filter(mvc_offset,mvc.t)
weights_filtered=fun.filter(weights_offset,weights.t)
fatigue_filtered=fun.filter(fatigue_offset,fatigue.t)
# Out:
# [-0.0017203399606160645 -0.026701732771783917 0.05365988902228464 ...
#  0.00045132660424230294 -0.0036405702752915843 0.007200317959197911]
# [0.0047413143103252455 0.015464574572444002 -0.035566208410906935 ...
#  -0.007020637796118237 -0.008864012880281304 0.02098136712682228]
# [0.012718010928653798 -0.024699716589927583 0.03471077654222201 ...
#  0.027023580453110353 -0.01152307857197778 -0.0027736439002972796]

# %%
mvc_s,mvc_e,weights_s,weights_e,fatigue_s,fatigue_e= lf3.get_bursts(mvc_filtered,weights_filtered,fatigue_filtered)
# Out:
# Click once to start zoom
# c:\Users\sophi\Desktop\BSV_Praktikum\BSV_Prak_3\Python Code\Lab3Functions.py:47: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   plt.waitforbuttonpress()
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\sophi\Desktop\BSV_Praktikum\BSV_Prak_3\Python Code\Vorverarbeitung der Rohdaten.ipynb Zelle 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/sophi/Desktop/BSV_Praktikum/BSV_Prak_3/Python%20Code/Vorverarbeitung%20der%20Rohdaten.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> mvc_s,mvc_e,weights_s,weights_e,fatigue_s,fatigue_e= lf3.get_bursts(mvc_filtered,weights_filtered,fatigue_filtered)
#
# File c:\Users\sophi\Desktop\BSV_Praktikum\BSV_Prak_3\Python Code\Lab3Functions.py:80, in get_bursts(mvc_emg_filtered, weights_emg_filtered, fatigue_emg_filtered)
#      78 fatigue_end = np.empty(number_bursts)
#      79 for i in range(number_bursts):
# ---> 80     mvc_start[i], mvc_end[i] = get_individual_burst(mvc_emg_filtered)
#      81 for i in range(number_bursts):
#      82     weights_start[i], weights_end[i] = get_individual_burst(weights_emg_filtered)
#
# File c:\Users\sophi\Desktop\BSV_Praktikum\BSV_Prak_3\Python Code\Lab3Functions.py:47, in get_bursts.<locals>.get_individual_burst(x)
#      44 plt.plot(x)
#      46 tellme('Click once to start zoom')
# ---> 47 plt.waitforbuttonpress()
#      49 while True:
#      50     tellme('Select two corners of zoom, enter/return key to finish')
#
# File c:\Users\sophi\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py:2308, in waitforbuttonpress(timeout)
#    2306 @_copy_docstring_and_deprecators(Figure.waitforbuttonpress)
#    2307 def waitforbuttonpress(timeout=-1):
# -> 2308     return gcf().waitforbuttonpress(timeout=timeout)
#
# File c:\Users\sophi\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\figure.py:3132, in Figure.waitforbuttonpress(self, timeout)
#    3129     event = ev
#    3130     self.canvas.stop_event_loop()
# -> 3132 _blocking_input.blocking_input_loop(
#    3133     self, ["button_press_event", "key_press_event"], timeout, handler)
#    3135 return None if event is None else event.name == "key_press_event"
#
# File c:\Users\sophi\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\_blocking_input.py:26, in blocking_input_loop(figure, event_names, timeout, handler)
#      24 cids = [figure.canvas.mpl_connect(name, handler) for name in event_names]
#      25 try:
# ---> 26     figure.canvas.start_event_loop(timeout)  # Start event loop.
#      27 finally:  # Run even on exception like ctrl-c.
#      28     # Disconnect the callbacks.
#      29     for cid in cids:
#
# File c:\Users\sophi\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\backend_bases.py:2519, in FigureCanvasBase.start_event_loop(self, timeout)
#    2517 while self._looping and counter * timestep < timeout:
#    2518     self.flush_events()
# -> 2519     time.sleep(timestep)
#    2520     counter += 1
#
# KeyboardInterrupt:
